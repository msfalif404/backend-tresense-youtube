# %%
import requests
import pandas as pd
import random

# %%
API_KEY = "AIzaSyCncJE9s_IWCc6ZbePJMDAdbFnuZFoNuU8"  

def get_random_video_ids_from_indonesia(max_channels=10, videos_per_channel=10):
    POPULAR_KEYWORDS = [
        "musik", "berita", "film", "komedi", "game", "politik", "selebriti", "hiburan", 
        "vlog", "live", "tutorial", "review", "travel", "masakan", "teknologi", "seni", 
        "olahraga", "kesehatan", "pendidikan", "fashion"
    ]
    collected_video_ids = []

    for _ in range(max_channels):
        keyword = random.choice(POPULAR_KEYWORDS)
        print(f"🔍 Mencari dengan keyword: {keyword}")

        search_url = "https://www.googleapis.com/youtube/v3/search"
        search_params = {
            "part": "snippet",
            "q": keyword,
            "type": "video",
            "regionCode": "ID",
            "maxResults": 10,
            "key": API_KEY
        }

        res = requests.get(search_url, params=search_params)
        data = res.json()

        if "items" not in data:
            continue

        channels = list(set([item['snippet']['channelId'] for item in data['items']]))

        for channel_id in channels[:1]:
            channel_video_url = "https://www.googleapis.com/youtube/v3/search"
            channel_params = {
                "part": "snippet",
                "channelId": channel_id,
                "order": "date",
                "maxResults": videos_per_channel,
                "type": "video",
                "key": API_KEY
            }

            video_res = requests.get(channel_video_url, params=channel_params)
            video_data = video_res.json()

            if "items" in video_data:
                for item in video_data['items']:
                    video_id = item['id']['videoId']
                    collected_video_ids.append(video_id)

    return list(set(collected_video_ids))

if __name__ == "__main__":
    video_ids = get_random_video_ids_from_indonesia()
    print(f"\n🎯 Video ID yang didapat: {video_ids}")
# Out:
# 🔍 Mencari dengan keyword: game
# 🔍 Mencari dengan keyword: selebriti
# 🔍 Mencari dengan keyword: film
# 🔍 Mencari dengan keyword: game
# 🔍 Mencari dengan keyword: selebriti
# 🔍 Mencari dengan keyword: selebriti
# 🔍 Mencari dengan keyword: film
# 🔍 Mencari dengan keyword: selebriti
# 🔍 Mencari dengan keyword: berita
# 🔍 Mencari dengan keyword: live
#
# 🎯 Video ID yang didapat: ['N3jYG2rp_j4', '3SxwH7BDA-A', '2XZ9NGsbzXg', 'QPRhoVcE57w', 'ttQM0wyW3ng', 'VUSi88CVogY', 'cD13NuCi4bI', 'wCe2VR9y0Qk', 'RCYsPTEH1i4', '8CidXiOZSNQ', 'VbqChBy4ZGg', '1aeCrhiZLfw', 'bhs_O4zecpo', 'j8-56RxZyl0', '231J-zBjQdU', 'vUSdYXmEPnI', 'yb7b_Qg6MDM', 'uHMD9lqEKUA', 'QFjy63NWArk', 'oE2wi4N4kZE', 'kLoqfesDKhk', 'EpRVwxP2l-I', 'sswrEV1OTyw', 'sA6KlsHRpBU', '_XbVv7EIp5M', 'Yujjmw3ZO14', 'CjA6YPuWif4', 'faFbUS4JTpY', 'MqLGeVkT7LA', '2Jx84mj0lKw', 'N3jYG2rp_j4', '3SxwH7BDA-A', '2XZ9NGsbzXg', 'QPRhoVcE57w', 'ttQM0wyW3ng', 'VUSi88CVogY', 'cD13NuCi4bI', 'wCe2VR9y0Qk', 'RCYsPTEH1i4', 'qT0E0wzjn2k', 'VbqChBy4ZGg', '1aeCrhiZLfw', 'bhs_O4zecpo', 'j8-56RxZyl0', '231J-zBjQdU', 'vUSdYXmEPnI', 'yb7b_Qg6MDM', 'uHMD9lqEKUA', 'QFjy63NWArk', 'oE2wi4N4kZE', 'VbqChBy4ZGg', '1aeCrhiZLfw', 'bhs_O4zecpo', 'j8-56RxZyl0', '231J-zBjQdU', 'vUSdYXmEPnI', 'yb7b_Qg6MDM', 'uHMD9lqEKUA', 'QFjy63NWArk', 'oE2wi4N4kZE', 'kLoqfesDKhk', 'EpRVwxP2l-I', 'sswrEV1OTyw', 'sA6KlsHRpBU', '_XbVv7EIp5M', 'Yujjmw3ZO14', 'CjA6YPuWif4', 'faFbUS4JTpY', 'MqLGeVkT7LA', '2Jx84mj0lKw', 'VbqChBy4ZGg', '1aeCrhiZLfw', 'bhs_O4zecpo', 'j8-56RxZyl0', '231J-zBjQdU', 'vUSdYXmEPnI', 'yb7b_Qg6MDM', 'uHMD9lqEKUA', 'QFjy63NWArk', 'oE2wi4N4kZE', 'iLtPS721KtA', 'cmBwq6GzMSM', '_am1b9MdMkM', 'dD--PvwqNq0', 'sfWZZIewxZA', '5UTG9M5DhSk', 'kkPtfNJSwJE', 'URsmc0qc6VA', 'Huz1FCi4VLo', '8d1p2vK_RlE', 'EXcgUUzYo_k', 'xQkj_VpVvco', 'pyGqcGOp1-g', 'UrmJUr6Gr-I', 'iURAlsDfl0k', 'PtGND-ebS-A', 'ETfGaunzqIM', 'pDfSKdNAsvs', 'JD8BEtCokps', 'Nd774cUzFOI']

# %%
# hapus video duplikat
video_ids = list(set(video_ids))
len(video_ids)
# Out:
# 51
